# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
def iteration_training_model(lst):
    df = pd.read_csv('credit_card_churn.csv')
    df = df.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2', 'CLIENTNUM'], axis=1)
    ##### remove outlier
    df = df.loc[df['Customer_Age'] <= 66]
    df = df.loc[df['Total_Ct_Chng_Q4_Q1'] <= 1.6]
    df = df.loc[df['Months_Inactive_12_mon'] < 6]
    df = df.loc[df['Total_Amt_Chng_Q4_Q1'] <= 1.6]

    ##### correct skewed data
    df['Credit_Limit'] = np.log10(df['Credit_Limit'])
    fitted_data, fitted_lambda = stats.boxcox(df['Avg_Open_To_Buy'])
    df['Avg_Open_To_Buy'] = fitted_data
    df['Total_Trans_Amt'] = np.log10(df['Total_Trans_Amt'])
    df['Avg_Utilization_Ratio'] = (df['Avg_Utilization_Ratio'])**(1/2)

    df = df.drop(lst, axis = 1)

    x = df.drop(['Attrition_Flag'], axis=1)
    y = df['Attrition_Flag']
    y = y.replace(['Existing Customer', 'Attrited Customer'], [0, 1])
    x = pd.get_dummies(x)
    x = x.values
    y = y.values
    scaler = MinMaxScaler()
    x = scaler.fit_transform(x)
    
    x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.1, random_state = 1)
    parameters = {'C':[0.01, 0.1, 1, 10, 100],
                    'solver':('newton-cg', 'liblinear', 'sag', 'saga')}
    
    logisReg = LogisticRegression()
    clf = GridSearchCV(logisReg, parameters, scoring='f1', verbose=0, return_train_score=True, n_jobs=-1, cv = 10)
    clf.fit(x_train, y_train)
    
    y_pred = clf.predict(x_test)
    print(lst)
    print("Classification report \n=======================")
    print(classification_report(y_true=y_test, y_pred=y_pred))
    print("Confusion matrix \n=======================")
    print(confusion_matrix(y_true=y_test, y_pred=y_pred))

# %%
import itertools
cols = ['Customer_Age', 'Gender', 'Dependent_count',
       'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
       'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']
for i in range(1,3,1):
    comb = itertools.combinations(range(19), i)
    for val in comb:
        lst = []
        for j in range(i):
            lst.append(cols[val[j]])
        iteration_training_model(lst)
# Out:
# ['Customer_Age']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.66      0.74       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.82      0.85       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 56 109]]
# ['Gender']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.84      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 57 108]]
# ['Dependent_count']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 57 108]]
# ['Education_Level']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.66      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.82      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 56 109]]
# ['Marital_Status']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.64      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 59 106]]
# ['Income_Category']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       823
#            1       0.83      0.67      0.74       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.82      0.85       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 55 110]]
# ['Card_Category']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 57 108]]
# ['Months_on_book']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       823
#            1       0.84      0.67      0.74       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.82      0.85       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 55 110]]
# ['Total_Relationship_Count']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.79      0.65      0.72       165
#
#     accuracy                           0.91       988
#    macro avg       0.86      0.81      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[795  28]
#  [ 57 108]]
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# ['Months_Inactive_12_mon']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.84      0.61      0.71       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.79      0.83       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[804  19]
#  [ 64 101]]
# ['Contacts_Count_12_mon']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.65      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.87      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 58 107]]
# ['Credit_Limit']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.64      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 59 106]]
# ['Total_Revolving_Bal']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.66      0.74       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.82      0.85       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 56 109]]
# ['Avg_Open_To_Buy']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.81      0.62      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 62 103]]
# ['Total_Amt_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.81      0.65      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.87      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[798  25]
#  [ 58 107]]
# ['Total_Trans_Amt']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       823
#            1       0.84      0.56      0.67       165
#
#     accuracy                           0.91       988
#    macro avg       0.88      0.77      0.81       988
# weighted avg       0.90      0.91      0.90       988
#
# Confusion matrix
# =======================
# [[805  18]
#  [ 73  92]]
# ['Total_Trans_Ct']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       823
#            1       0.86      0.47      0.60       165
#
#     accuracy                           0.90       988
#    macro avg       0.88      0.73      0.77       988
# weighted avg       0.89      0.90      0.88       988
#
# Confusion matrix
# =======================
# [[810  13]
#  [ 88  77]]
# ['Total_Ct_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.79      0.64      0.70       165
#
#     accuracy                           0.91       988
#    macro avg       0.86      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[795  28]
#  [ 60 105]]
# ['Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.64      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.80      0.83       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 60 105]]
# ['Customer_Age', 'Gender']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.84      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[803  20]
#  [ 58 107]]
# ['Customer_Age', 'Dependent_count']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 57 108]]
# ['Customer_Age', 'Education_Level']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.66      0.74       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.82      0.85       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 56 109]]
# ['Customer_Age', 'Marital_Status']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.64      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 59 106]]
# ['Customer_Age', 'Income_Category']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.66      0.74       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.82      0.85       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 56 109]]
# ['Customer_Age', 'Card_Category']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 57 108]]
# ['Customer_Age', 'Months_on_book']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.66      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.82      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 56 109]]
# ['Customer_Age', 'Total_Relationship_Count']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.80      0.66      0.72       165
#
#     accuracy                           0.91       988
#    macro avg       0.86      0.81      0.84       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[795  28]
#  [ 56 109]]
# ['Customer_Age', 'Months_Inactive_12_mon']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.84      0.62      0.71       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.80      0.83       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[804  19]
#  [ 63 102]]
# ['Customer_Age', 'Contacts_Count_12_mon']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.65      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.87      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 58 107]]
# ['Customer_Age', 'Credit_Limit']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.64      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 59 106]]
# ['Customer_Age', 'Total_Revolving_Bal']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.66      0.74       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.82      0.85       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 56 109]]
# ['Customer_Age', 'Avg_Open_To_Buy']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.81      0.62      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 62 103]]
# ['Customer_Age', 'Total_Amt_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.81      0.65      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.87      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[798  25]
#  [ 57 108]]
# ['Customer_Age', 'Total_Trans_Amt']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       823
#            1       0.84      0.56      0.67       165
#
#     accuracy                           0.91       988
#    macro avg       0.88      0.77      0.81       988
# weighted avg       0.90      0.91      0.90       988
#
# Confusion matrix
# =======================
# [[805  18]
#  [ 73  92]]
# ['Customer_Age', 'Total_Trans_Ct']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       823
#            1       0.84      0.47      0.60       165
#
#     accuracy                           0.90       988
#    macro avg       0.87      0.72      0.77       988
# weighted avg       0.89      0.90      0.88       988
#
# Confusion matrix
# =======================
# [[808  15]
#  [ 88  77]]
# ['Customer_Age', 'Total_Ct_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.79      0.64      0.70       165
#
#     accuracy                           0.91       988
#    macro avg       0.86      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[795  28]
#  [ 60 105]]
# ['Customer_Age', 'Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.64      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 59 106]]
# ['Gender', 'Dependent_count']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.84      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 58 107]]
# ['Gender', 'Education_Level']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       823
#            1       0.85      0.66      0.74       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.82      0.85       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[804  19]
#  [ 56 109]]
# ['Gender', 'Marital_Status']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.85      0.63      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.80      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[805  18]
#  [ 61 104]]
# ['Gender', 'Income_Category']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.64      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 59 106]]
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# ['Gender', 'Card_Category']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.84      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 58 107]]
# ['Gender', 'Months_on_book']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       823
#            1       0.85      0.66      0.74       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.82      0.85       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[804  19]
#  [ 56 109]]
# ['Gender', 'Total_Relationship_Count']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95       823
#            1       0.78      0.65      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.85      0.81      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[792  31]
#  [ 58 107]]
# ['Gender', 'Months_Inactive_12_mon']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.62      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.88      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 63 102]]
# ['Gender', 'Contacts_Count_12_mon']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.81      0.62      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 62 103]]
# ['Gender', 'Credit_Limit']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.84      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[803  20]
#  [ 58 107]]
# ['Gender', 'Total_Revolving_Bal']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.84      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 57 108]]
# ['Gender', 'Avg_Open_To_Buy']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.62      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 62 103]]
# ['Gender', 'Total_Amt_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.84      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 58 107]]
# ['Gender', 'Total_Trans_Amt']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       823
#            1       0.86      0.56      0.68       165
#
#     accuracy                           0.91       988
#    macro avg       0.89      0.77      0.82       988
# weighted avg       0.91      0.91      0.90       988
#
# Confusion matrix
# =======================
# [[808  15]
#  [ 72  93]]
# ['Gender', 'Total_Trans_Ct']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       823
#            1       0.84      0.45      0.59       165
#
#     accuracy                           0.89       988
#    macro avg       0.87      0.72      0.77       988
# weighted avg       0.89      0.89      0.88       988
#
# Confusion matrix
# =======================
# [[809  14]
#  [ 90  75]]
# ['Gender', 'Total_Ct_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.80      0.62      0.70       165
#
#     accuracy                           0.91       988
#    macro avg       0.86      0.79      0.82       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[797  26]
#  [ 63 102]]
# ['Gender', 'Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.64      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.80      0.83       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 60 105]]
# ['Dependent_count', 'Education_Level']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 57 108]]
# ['Dependent_count', 'Marital_Status']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.84      0.65      0.74       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.82      0.85       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[803  20]
#  [ 57 108]]
# ['Dependent_count', 'Income_Category']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 57 108]]
# ['Dependent_count', 'Card_Category']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 57 108]]
# ['Dependent_count', 'Months_on_book']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 57 108]]
# ['Dependent_count', 'Total_Relationship_Count']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.80      0.64      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.86      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[796  27]
#  [ 59 106]]
# ['Dependent_count', 'Months_Inactive_12_mon']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.64      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 59 106]]
# ['Dependent_count', 'Contacts_Count_12_mon']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.81      0.64      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 60 105]]
# ['Dependent_count', 'Credit_Limit']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.64      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.80      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 60 105]]
# ['Dependent_count', 'Total_Revolving_Bal']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 57 108]]
# ['Dependent_count', 'Avg_Open_To_Buy']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.80      0.62      0.70       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[798  25]
#  [ 62 103]]
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# ['Dependent_count', 'Total_Amt_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.84      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 58 107]]
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# ['Dependent_count', 'Total_Trans_Amt']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       823
#            1       0.83      0.57      0.68       165
#
#     accuracy                           0.91       988
#    macro avg       0.88      0.77      0.81       988
# weighted avg       0.90      0.91      0.90       988
#
# Confusion matrix
# =======================
# [[804  19]
#  [ 71  94]]
# ['Dependent_count', 'Total_Trans_Ct']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       823
#            1       0.83      0.46      0.59       165
#
#     accuracy                           0.89       988
#    macro avg       0.86      0.72      0.77       988
# weighted avg       0.89      0.89      0.88       988
#
# Confusion matrix
# =======================
# [[807  16]
#  [ 89  76]]
# ['Dependent_count', 'Total_Ct_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.80      0.63      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.86      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[797  26]
#  [ 61 104]]
# ['Dependent_count', 'Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.64      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.87      0.81      0.83       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 59 106]]
# ['Education_Level', 'Marital_Status']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.64      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 59 106]]
# ['Education_Level', 'Income_Category']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.66      0.74       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.82      0.85       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 56 109]]
# ['Education_Level', 'Card_Category']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.66      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.82      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 56 109]]
# ['Education_Level', 'Months_on_book']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       823
#            1       0.83      0.67      0.74       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.82      0.85       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 55 110]]
# ['Education_Level', 'Total_Relationship_Count']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.79      0.65      0.72       165
#
#     accuracy                           0.91       988
#    macro avg       0.86      0.81      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[795  28]
#  [ 57 108]]
# ['Education_Level', 'Months_Inactive_12_mon']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.84      0.62      0.71       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.80      0.83       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[804  19]
#  [ 63 102]]
# ['Education_Level', 'Contacts_Count_12_mon']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.65      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.87      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 58 107]]
# ['Education_Level', 'Credit_Limit']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.85      0.64      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[804  19]
#  [ 59 106]]
# ['Education_Level', 'Total_Revolving_Bal']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.66      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.82      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 56 109]]
# ['Education_Level', 'Avg_Open_To_Buy']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.62      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.88      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 62 103]]
# ['Education_Level', 'Total_Amt_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 57 108]]
# ['Education_Level', 'Total_Trans_Amt']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       823
#            1       0.85      0.56      0.67       165
#
#     accuracy                           0.91       988
#    macro avg       0.88      0.77      0.81       988
# weighted avg       0.91      0.91      0.90       988
#
# Confusion matrix
# =======================
# [[807  16]
#  [ 73  92]]
# ['Education_Level', 'Total_Trans_Ct']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       823
#            1       0.85      0.45      0.59       165
#
#     accuracy                           0.90       988
#    macro avg       0.88      0.72      0.77       988
# weighted avg       0.89      0.90      0.88       988
#
# Confusion matrix
# =======================
# [[810  13]
#  [ 90  75]]
# ['Education_Level', 'Total_Ct_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.80      0.62      0.70       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[798  25]
#  [ 62 103]]
# ['Education_Level', 'Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.62      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.88      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 62 103]]
# ['Marital_Status', 'Income_Category']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.84      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 58 107]]
# ['Marital_Status', 'Card_Category']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.84      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[803  20]
#  [ 58 107]]
# ['Marital_Status', 'Months_on_book']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.84      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 57 108]]
# ['Marital_Status', 'Total_Relationship_Count']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.80      0.64      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[797  26]
#  [ 60 105]]
# ['Marital_Status', 'Months_Inactive_12_mon']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.62      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 62 103]]
# ['Marital_Status', 'Contacts_Count_12_mon']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 57 108]]
# ['Marital_Status', 'Credit_Limit']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.85      0.64      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[804  19]
#  [ 60 105]]
# ['Marital_Status', 'Total_Revolving_Bal']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.84      0.64      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[803  20]
#  [ 59 106]]
# ['Marital_Status', 'Avg_Open_To_Buy']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.84      0.62      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.80      0.83       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[804  19]
#  [ 62 103]]
# ['Marital_Status', 'Total_Amt_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.85      0.65      0.74       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.82      0.85       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[804  19]
#  [ 57 108]]
# ['Marital_Status', 'Total_Trans_Amt']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       823
#            1       0.84      0.56      0.67       165
#
#     accuracy                           0.91       988
#    macro avg       0.88      0.77      0.81       988
# weighted avg       0.90      0.91      0.90       988
#
# Confusion matrix
# =======================
# [[806  17]
#  [ 73  92]]
# ['Marital_Status', 'Total_Trans_Ct']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       823
#            1       0.84      0.45      0.59       165
#
#     accuracy                           0.89       988
#    macro avg       0.87      0.72      0.77       988
# weighted avg       0.89      0.89      0.88       988
#
# Confusion matrix
# =======================
# [[809  14]
#  [ 90  75]]
# ['Marital_Status', 'Total_Ct_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       823
#            1       0.78      0.61      0.68       165
#
#     accuracy                           0.91       988
#    macro avg       0.85      0.79      0.81       988
# weighted avg       0.90      0.91      0.90       988
#
# Confusion matrix
# =======================
# [[794  29]
#  [ 64 101]]
# ['Marital_Status', 'Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.65      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 57 108]]
# ['Income_Category', 'Card_Category']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       823
#            1       0.83      0.67      0.74       165
#
# ...
#
# Confusion matrix
# =======================
# [[797  26]
#  [ 61 104]]
# ['Contacts_Count_12_mon', 'Total_Amt_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.81      0.66      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.87      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[797  26]
#  [ 56 109]]
# ['Contacts_Count_12_mon', 'Total_Trans_Amt']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       823
#            1       0.80      0.55      0.65       165
#
#     accuracy                           0.90       988
#    macro avg       0.86      0.76      0.80       988
# weighted avg       0.90      0.90      0.89       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 74  91]]
# ['Contacts_Count_12_mon', 'Total_Trans_Ct']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.94       823
#            1       0.82      0.42      0.56       165
#
#     accuracy                           0.89       988
#    macro avg       0.86      0.70      0.75       988
# weighted avg       0.88      0.89      0.87       988
#
# Confusion matrix
# =======================
# [[808  15]
#  [ 95  70]]
# ['Contacts_Count_12_mon', 'Total_Ct_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       823
#            1       0.76      0.61      0.68       165
#
#     accuracy                           0.90       988
#    macro avg       0.84      0.78      0.81       988
# weighted avg       0.90      0.90      0.90       988
#
# Confusion matrix
# =======================
# [[792  31]
#  [ 65 100]]
# ['Contacts_Count_12_mon', 'Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.61      0.70       165
#
#     accuracy                           0.91       988
#    macro avg       0.88      0.79      0.82       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 65 100]]
# ['Credit_Limit', 'Total_Revolving_Bal']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.85      0.64      0.73       165
#
#     accuracy                           0.92       988
#    macro avg       0.89      0.81      0.84       988
# weighted avg       0.92      0.92      0.92       988
#
# Confusion matrix
# =======================
# [[804  19]
#  [ 60 105]]
# ['Credit_Limit', 'Avg_Open_To_Buy']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.62      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 62 103]]
# ['Credit_Limit', 'Total_Amt_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       823
#            1       0.84      0.63      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.80      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[803  20]
#  [ 61 104]]
# ['Credit_Limit', 'Total_Trans_Amt']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.95       823
#            1       0.85      0.55      0.66       165
#
#     accuracy                           0.91       988
#    macro avg       0.88      0.76      0.81       988
# weighted avg       0.90      0.91      0.90       988
#
# Confusion matrix
# =======================
# [[807  16]
#  [ 75  90]]
# ['Credit_Limit', 'Total_Trans_Ct']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       823
#            1       0.83      0.45      0.59       165
#
#     accuracy                           0.89       988
#    macro avg       0.87      0.72      0.76       988
# weighted avg       0.89      0.89      0.88       988
#
# Confusion matrix
# =======================
# [[808  15]
#  [ 90  75]]
# ['Credit_Limit', 'Total_Ct_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95       823
#            1       0.78      0.62      0.69       165
#
#     accuracy                           0.91       988
#    macro avg       0.85      0.79      0.82       988
# weighted avg       0.90      0.91      0.90       988
#
# Confusion matrix
# =======================
# [[794  29]
#  [ 63 102]]
# ['Credit_Limit', 'Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.63      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 61 104]]
# ['Total_Revolving_Bal', 'Avg_Open_To_Buy']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.62      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 62 103]]
# ['Total_Revolving_Bal', 'Total_Amt_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.81      0.65      0.72       165
#
#     accuracy                           0.92       988
#    macro avg       0.87      0.81      0.84       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[798  25]
#  [ 58 107]]
# ['Total_Revolving_Bal', 'Total_Trans_Amt']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       823
#            1       0.84      0.55      0.67       165
#
#     accuracy                           0.91       988
#    macro avg       0.88      0.77      0.81       988
# weighted avg       0.90      0.91      0.90       988
#
# Confusion matrix
# =======================
# [[806  17]
#  [ 74  91]]
# ['Total_Revolving_Bal', 'Total_Trans_Ct']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       823
#            1       0.85      0.47      0.60       165
#
#     accuracy                           0.90       988
#    macro avg       0.87      0.72      0.77       988
# weighted avg       0.89      0.90      0.88       988
#
# Confusion matrix
# =======================
# [[809  14]
#  [ 88  77]]
# ['Total_Revolving_Bal', 'Total_Ct_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.79      0.64      0.70       165
#
#     accuracy                           0.91       988
#    macro avg       0.86      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[795  28]
#  [ 60 105]]
# ['Total_Revolving_Bal', 'Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.79      0.62      0.70       165
#
#     accuracy                           0.91       988
#    macro avg       0.86      0.80      0.82       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[796  27]
#  [ 62 103]]
# ['Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.82      0.63      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 61 104]]
# ['Avg_Open_To_Buy', 'Total_Trans_Amt']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.95       823
#            1       0.85      0.53      0.65       165
#
#     accuracy                           0.91       988
#    macro avg       0.88      0.76      0.80       988
# weighted avg       0.90      0.91      0.90       988
#
# Confusion matrix
# =======================
# [[807  16]
#  [ 77  88]]
# ['Avg_Open_To_Buy', 'Total_Trans_Ct']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       823
#            1       0.84      0.44      0.58       165
#
#     accuracy                           0.89       988
#    macro avg       0.87      0.71      0.76       988
# weighted avg       0.89      0.89      0.88       988
#
# Confusion matrix
# =======================
# [[809  14]
#  [ 92  73]]
# ['Avg_Open_To_Buy', 'Total_Ct_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       823
#            1       0.77      0.59      0.67       165
#
#     accuracy                           0.90       988
#    macro avg       0.85      0.78      0.81       988
# weighted avg       0.90      0.90      0.90       988
#
# Confusion matrix
# =======================
# [[794  29]
#  [ 67  98]]
# ['Avg_Open_To_Buy', 'Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.83      0.63      0.71       165
#
#     accuracy                           0.92       988
#    macro avg       0.88      0.80      0.83       988
# weighted avg       0.91      0.92      0.91       988
#
# Confusion matrix
# =======================
# [[801  22]
#  [ 61 104]]
# ['Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       823
#            1       0.84      0.56      0.67       165
#
#     accuracy                           0.91       988
#    macro avg       0.88      0.77      0.81       988
# weighted avg       0.90      0.91      0.90       988
#
# Confusion matrix
# =======================
# [[806  17]
#  [ 73  92]]
# ['Total_Amt_Chng_Q4_Q1', 'Total_Trans_Ct']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       823
#            1       0.84      0.47      0.60       165
#
#     accuracy                           0.90       988
#    macro avg       0.87      0.72      0.77       988
# weighted avg       0.89      0.90      0.88       988
#
# Confusion matrix
# =======================
# [[808  15]
#  [ 88  77]]
# ['Total_Amt_Chng_Q4_Q1', 'Total_Ct_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       823
#            1       0.78      0.59      0.67       165
#
#     accuracy                           0.90       988
#    macro avg       0.85      0.78      0.81       988
# weighted avg       0.90      0.90      0.90       988
#
# Confusion matrix
# =======================
# [[795  28]
#  [ 67  98]]
# ['Total_Amt_Chng_Q4_Q1', 'Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       823
#            1       0.81      0.64      0.71       165
#
#     accuracy                           0.91       988
#    macro avg       0.87      0.80      0.83       988
# weighted avg       0.91      0.91      0.91       988
#
# Confusion matrix
# =======================
# [[798  25]
#  [ 60 105]]
# ['Total_Trans_Amt', 'Total_Trans_Ct']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.93       823
#            1       0.78      0.43      0.55       165
#
#     accuracy                           0.88       988
#    macro avg       0.84      0.70      0.74       988
# weighted avg       0.88      0.88      0.87       988
#
# Confusion matrix
# =======================
# [[803  20]
#  [ 94  71]]
# ['Total_Trans_Amt', 'Total_Ct_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       823
#            1       0.80      0.57      0.66       165
#
#     accuracy                           0.90       988
#    macro avg       0.86      0.77      0.80       988
# weighted avg       0.90      0.90      0.90       988
#
# Confusion matrix
# =======================
# [[799  24]
#  [ 71  94]]
# ['Total_Trans_Amt', 'Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       823
#            1       0.81      0.55      0.65       165
#
#     accuracy                           0.90       988
#    macro avg       0.86      0.76      0.80       988
# weighted avg       0.90      0.90      0.89       988
#
# Confusion matrix
# =======================
# [[802  21]
#  [ 75  90]]
# ['Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       823
#            1       0.76      0.44      0.55       165
#
#     accuracy                           0.88       988
#    macro avg       0.83      0.70      0.74       988
# weighted avg       0.87      0.88      0.87       988
#
# Confusion matrix
# =======================
# [[800  23]
#  [ 93  72]]
# ['Total_Trans_Ct', 'Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       823
#            1       0.84      0.43      0.57       165
#
#     accuracy                           0.89       988
#    macro avg       0.87      0.71      0.75       988
# weighted avg       0.89      0.89      0.88       988
#
# Confusion matrix
# =======================
# [[809  14]
#  [ 94  71]]
# ['Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']
# Classification report
# =======================
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       823
#            1       0.76      0.63      0.69       165
#
#     accuracy                           0.91       988
#    macro avg       0.85      0.80      0.82       988
# weighted avg       0.90      0.91      0.90       988
#
# Confusion matrix
# =======================
# [[791  32]
#  [ 61 104]]
