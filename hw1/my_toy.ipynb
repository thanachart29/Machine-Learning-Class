# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
def iteration_training_model(lst):
    df = pd.read_csv('credit_card_churn.csv')
    df = df.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2', 'CLIENTNUM'], axis=1)
    ##### remove outlier
    df = df.loc[df['Customer_Age'] <= 66]
    df = df.loc[df['Total_Ct_Chng_Q4_Q1'] <= 1.6]
    df = df.loc[df['Months_Inactive_12_mon'] < 6]
    df = df.loc[df['Total_Amt_Chng_Q4_Q1'] <= 1.6]

    ##### correct skewed data
    df['Credit_Limit'] = np.log10(df['Credit_Limit'])
    fitted_data, fitted_lambda = stats.boxcox(df['Avg_Open_To_Buy'])
    df['Avg_Open_To_Buy'] = fitted_data
    df['Total_Trans_Amt'] = np.log10(df['Total_Trans_Amt'])
    df['Avg_Utilization_Ratio'] = (df['Avg_Utilization_Ratio'])**(1/2)

    df = df.drop(lst, axis = 1)

    x = df.drop(['Attrition_Flag'], axis=1)
    y = df['Attrition_Flag']
    y = y.replace(['Existing Customer', 'Attrited Customer'], [0, 1])
    x = pd.get_dummies(x)
    x = x.values
    y = y.values
    scaler = MinMaxScaler()
    x = scaler.fit_transform(x)
    
    x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.1, random_state = 1, shuffle=True)
    parameters = {'C':[0.01, 0.1, 1, 10, 100],
                    'solver':('newton-cg', 'liblinear', 'sag', 'saga')}
    
    kf = KFold(n_splits=10, shuffle=True, random_state=1)
    logisReg = LogisticRegression()
    clf = GridSearchCV(logisReg, parameters, scoring='f1', verbose=5, return_train_score=True, n_jobs=-1, cv = kf)
    clf.fit(x_train, y_train)
    
    y_pred = clf.predict(x_test)
    print(lst)
    print("Classification report \n=======================")
    print(classification_report(y_true=y_test, y_pred=y_pred))
    print("Confusion matrix \n=======================")
    print(confusion_matrix(y_true=y_test, y_pred=y_pred))

# %%
import itertools
cols = ['Customer_Age', 'Gender', 'Dependent_count',
       'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
       'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']
for i in range(1,3,1):
    comb = itertools.combinations(range(19), i)
    for val in comb:
        lst = []
        for j in range(i):
            lst.append(cols[val[j]])
        iteration_training_model(lst)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Gender']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# ['Customer_Age', 'Dependent_count']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Education_Level']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Marital_Status']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.8______________0.65_____________0.72
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Income_Category']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Card_Category']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Months_on_book']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Total_Relationship_Count']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.96_____________0.95
# _______1_________0.76______________0.61_____________0.68
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Months_Inactive_12_mon']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.63_____________0.7
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# ['Customer_Age', 'Contacts_Count_12_mon']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Credit_Limit']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Total_Revolving_Bal']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Avg_Open_To_Buy']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Total_Amt_Chng_Q4_Q1']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Total_Trans_Amt']
# _______________precision__________recall__________f1-score
# _______0_________0.92______________0.97_____________0.94
# _______1_________0.78______________0.57_____________0.66
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Total_Trans_Ct']
# _______________precision__________recall__________f1-score
# _______0_________0.9______________0.97_____________0.94
# _______1_________0.77______________0.47_____________0.58
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Total_Ct_Chng_Q4_Q1']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.78______________0.61_____________0.69
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Customer_Age', 'Avg_Utilization_Ratio']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Dependent_count']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Education_Level']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Marital_Status']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Income_Category']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Card_Category']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Months_on_book']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Total_Relationship_Count']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.96_____________0.94
# _______1_________0.76______________0.61_____________0.67
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Months_Inactive_12_mon']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.78______________0.63_____________0.7
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Contacts_Count_12_mon']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.7
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Credit_Limit']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.8______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Total_Revolving_Bal']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Avg_Open_To_Buy']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.78______________0.64_____________0.7
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Total_Amt_Chng_Q4_Q1']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Total_Trans_Amt']
# _______________precision__________recall__________f1-score
# _______0_________0.92______________0.97_____________0.94
# _______1_________0.78______________0.57_____________0.65
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Total_Trans_Ct']
# _______________precision__________recall__________f1-score
# _______0_________0.9______________0.97_____________0.94
# _______1_________0.76______________0.46_____________0.58
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Total_Ct_Chng_Q4_Q1']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.96_____________0.95
# _______1_________0.77______________0.62_____________0.68
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Gender', 'Avg_Utilization_Ratio']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Education_Level']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Marital_Status']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Income_Category']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Card_Category']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Months_on_book']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Total_Relationship_Count']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.77______________0.61_____________0.68
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Months_Inactive_12_mon']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.62_____________0.7
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# ['Dependent_count', 'Contacts_Count_12_mon']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.78______________0.64_____________0.7
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Credit_Limit']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Total_Revolving_Bal']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Avg_Open_To_Buy']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Total_Amt_Chng_Q4_Q1']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Total_Trans_Amt']
# _______________precision__________recall__________f1-score
# _______0_________0.92______________0.97_____________0.94
# _______1_________0.78______________0.56_____________0.65
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Total_Trans_Ct']
# _______________precision__________recall__________f1-score
# _______0_________0.9______________0.97_____________0.94
# _______1_________0.76______________0.47_____________0.58
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Total_Ct_Chng_Q4_Q1']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.96_____________0.95
# _______1_________0.77______________0.61_____________0.68
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Dependent_count', 'Avg_Utilization_Ratio']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Education_Level', 'Marital_Status']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Education_Level', 'Income_Category']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Education_Level', 'Card_Category']
# ...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Card_Category', 'Avg_Open_To_Buy']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Card_Category', 'Total_Amt_Chng_Q4_Q1']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Card_Category', 'Total_Trans_Amt']
# _______________precision__________recall__________f1-score
# _______0_________0.92______________0.97_____________0.94
# _______1_________0.77______________0.56_____________0.65
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# ['Card_Category', 'Total_Trans_Ct']
# _______________precision__________recall__________f1-score
# _______0_________0.91______________0.97_____________0.94
# _______1_________0.77______________0.47_____________0.58
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Card_Category', 'Total_Ct_Chng_Q4_Q1']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.77______________0.61_____________0.68
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Card_Category', 'Avg_Utilization_Ratio']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Months_on_book', 'Total_Relationship_Count']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.96_____________0.95
# _______1_________0.77______________0.61_____________0.68
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Months_on_book', 'Months_Inactive_12_mon']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.63_____________0.7
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Months_on_book', 'Contacts_Count_12_mon']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Months_on_book', 'Credit_Limit']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# ['Months_on_book', 'Total_Revolving_Bal']
# _______________precision__________recall__________f1-score
# _______0_________0.94______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.72
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Months_on_book', 'Avg_Open_To_Buy']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Months_on_book', 'Total_Amt_Chng_Q4_Q1']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.65_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\thana\Desktop\TheShit\FRA503\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# ['Months_on_book', 'Total_Trans_Amt']
# _______________precision__________recall__________f1-score
# _______0_________0.92______________0.97_____________0.94
# _______1_________0.78______________0.57_____________0.66
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Months_on_book', 'Total_Trans_Ct']
# _______________precision__________recall__________f1-score
# _______0_________0.9______________0.97_____________0.94
# _______1_________0.77______________0.47_____________0.58
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Months_on_book', 'Total_Ct_Chng_Q4_Q1']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.77______________0.61_____________0.68
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ['Months_on_book', 'Avg_Utilization_Ratio']
# _______________precision__________recall__________f1-score
# _______0_________0.93______________0.97_____________0.95
# _______1_________0.79______________0.64_____________0.71
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
